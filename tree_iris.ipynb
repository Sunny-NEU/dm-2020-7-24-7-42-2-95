# %% [markdown]
# ### 读取数据

# %%
import pandas as pd
from sklearn import datasets
X,y=datasets.load_iris(return_X_y=True) #X与y
target_names=datasets.load_iris().target_names #y的值列表:0:setosa,1:versicolor,2:virginica
feature_names=datasets.load_iris().feature_names #特征X的名称列表

# %% [markdown]
# ### 默认参数训练决策树模型

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier(max_depth=3)
clf = clf.fit(X, y)

# %% [markdown]
# ### 预测sepal length=6,sepal width=1,petal length=3,petal width=1的花类型

# %%
clf.predict([[6,1,3,1]])
# Out:
# array([1])

# %% [markdown]
# #### 预测为类型1，即versicolor

# %% [markdown]
# ### 决策树可视化

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.figure(figsize=(10,6))
tree.plot_tree(clf,filled=True)
# Out:
# [Text(209.25, 285.39000000000004, 'X[2] <= 2.45\nentropy = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(139.5, 203.85000000000002, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(279.0, 203.85000000000002, 'X[3] <= 1.75\nentropy = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(139.5, 122.31, 'X[2] <= 4.95\nentropy = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(69.75, 40.76999999999998, 'entropy = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(209.25, 40.76999999999998, 'entropy = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(418.5, 122.31, 'X[2] <= 4.85\nentropy = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(348.75, 40.76999999999998, 'entropy = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(488.25, 40.76999999999998, 'entropy = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %% [markdown]
# #### 从上面的决策数结构分析，可以看出当x[2]小于等于2.45cm时，即花瓣长度小于等于2.45cm时，最有可能是setosa
